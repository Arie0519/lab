# %%
# ライブラリのインポート
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt

# %%
# データが保存されているフォルダのパスを指定
folder_path = R'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701/'

# %%
file_pattern = '*.csv'
files = glob.glob(f'{folder_path}/{file_pattern}')
print(files)
# Out:
# ['C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM10.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM11.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM12.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM13.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM14.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM15.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM16.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM17.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM18.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM3.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM5.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM6.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM7.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM8.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141228-COM9.csv', 'C:/Users/sukegawa/Desktop/study/datasets/m5data/240701\\device-monitor-240701-141229-COM4.csv']

# %%
# データフレームのリストを作成
data_frames = []
for file in files:
    df = pd.read_csv(file)
    # ファイル名からCOM番号を抽出
    com_num = os.path.splitext(os.path.basename(file))[0].split('-COM')[-1]
    # 重複を削除し、最初に取得したデータを残す
    #df = df.groupby(['date', 'time', 'x', 'y']).first().reset_index()
    # "RSSI"の列名を""RSSI<COM番号>に変更"
    df = df.rename(columns={"RSSI": f"RSSI{com_num}"})
    data_frames.append(df)
print(data_frames)
# Out:
# [     date          time  RSSI10  x  y
# 0    7-01  14:08:09.299     -67  0  0
# 1    7-01  14:08:09.299     -66  0  0
# 2    7-01  14:08:09.822     -64  0  0
# 3    7-01  14:08:10.340     -63  0  0
# 4    7-01  14:08:10.340     -61  0  0
# ..    ...           ...     ... .. ..
# 225  7-01  14:11:50.670     -98  6  1
# 226  7-01  14:11:50.216     -69  6  0
# 227  7-01  14:11:50.216     -71  6  0
# 228  7-01  14:11:50.732     -72  6  0
# 229  7-01  14:11:54.751     -74  6  0
#
# [230 rows x 5 columns],      date          time  RSSI11  x  y
# 0    7-01  14:08:09.299     -85  0  0
# 1    7-01  14:08:09.822     -73  0  0
# 2    7-01  14:08:09.822     -72  0  0
# 3    7-01  14:08:10.340     -73  0  0
# 4    7-01  14:08:10.860     -81  0  0
# ..    ...           ...     ... .. ..
# 203  7-01  14:11:49.706     -66  6  0
# 204  7-01  14:11:50.483     -87  6  1
# 205  7-01  14:11:50.216     -85  6  0
# 206  7-01  14:11:50.732     -67  6  0
# 207  7-01  14:11:54.751     -79  6  0
#
# [208 rows x 5 columns],      date          time  RSSI12  x  y
# 0    7-01  14:08:09.299     -73  0  0
# 1    7-01  14:08:09.822     -75  0  0
# 2    7-01  14:08:09.822     -74  0  0
# 3    7-01  14:08:10.340     -76  0  0
# 4    7-01  14:08:10.860     -74  0  0
# ..    ...           ...     ... .. ..
# 222  7-01  14:11:49.194     -74  6  0
# 223  7-01  14:11:49.706     -64  6  0
# 224  7-01  14:11:50.216     -72  6  0
# 225  7-01  14:11:50.732     -74  6  0
# 226  7-01  14:11:54.751     -70  6  0
#
# [227 rows x 5 columns],      date          time  RSSI13  x  y
# 0    7-01  14:08:09.299     -74  0  0
# 1    7-01  14:08:09.822     -80  0  0
# 2    7-01  14:08:10.340     -70  0  0
# 3    7-01  14:08:10.860     -71  0  0
# 4    7-01  14:08:11.373     -74  0  0
# ..    ...           ...     ... .. ..
# 225  7-01  14:11:50.051     -93  6  1
# 226  7-01  14:11:49.706     -60  6  0
# 227  7-01  14:11:50.216     -56  6  0
# 228  7-01  14:11:50.732     -60  6  0
# 229  7-01  14:11:54.751     -49  6  0
#
# [230 rows x 5 columns],      date          time  RSSI14  x  y
# 0    7-01  14:08:09.299     -76  0  0
# 1    7-01  14:08:09.822     -75  0  0
# 2    7-01  14:08:10.340     -83  0  0
# 3    7-01  14:08:10.340     -74  0  0
# 4    7-01  14:08:10.860     -73  0  0
# ..    ...           ...     ... .. ..
# 222  7-01  14:11:50.670     -92  6  1
# 223  7-01  14:11:50.216     -61  6  0
# 224  7-01  14:11:50.732     -63  6  0
# 225  7-01  14:11:50.732     -64  6  0
# 226  7-01  14:11:54.751     -71  6  0
#
# [227 rows x 5 columns],      date          time  RSSI15  x  y
# 0    7-01  14:08:09.299     -62  0  0
# 1    7-01  14:08:09.822     -59  0  0
# 2    7-01  14:08:10.340     -65  0  0
# 3    7-01  14:08:10.860     -64  0  0
# 4    7-01  14:08:11.373     -64  0  0
# ..    ...           ...     ... .. ..
# 216  7-01  14:11:49.706     -67  6  0
# 217  7-01  14:11:50.216     -68  6  0
# 218  7-01  14:11:50.732     -67  6  0
# 219  7-01  14:11:50.732     -67  6  0
# 220  7-01  14:11:54.751     -70  6  0
#
# [221 rows x 5 columns],      date          time  RSSI16  x  y
# 0    7-01  14:08:09.299     -58  0  0
# 1    7-01  14:08:09.822     -68  0  0
# 2    7-01  14:08:09.822     -61  0  0
# 3    7-01  14:08:10.340     -63  0  0
# 4    7-01  14:08:10.860     -59  0  0
# ..    ...           ...     ... .. ..
# 207  7-01  14:11:49.706     -68  6  0
# 208  7-01  14:11:50.216     -79  6  0
# 209  7-01  14:11:50.216     -66  6  0
# 210  7-01  14:11:50.732     -67  6  0
# 211  7-01  14:11:54.751     -67  6  0
#
# [212 rows x 5 columns],      date          time  RSSI17  x  y
# 0    7-01  14:08:09.299     -49  0  0
# 1    7-01  14:08:09.822     -49  0  0
# 2    7-01  14:08:10.340     -50  0  0
# 3    7-01  14:08:10.860     -50  0  0
# 4    7-01  14:08:10.860     -48  0  0
# ..    ...           ...     ... .. ..
# 224  7-01  14:11:49.706     -66  6  0
# 225  7-01  14:11:50.216     -64  6  0
# 226  7-01  14:11:50.216     -69  6  0
# 227  7-01  14:11:50.732     -66  6  0
# 228  7-01  14:11:54.751     -69  6  0
#
# [229 rows x 5 columns],      date          time  RSSI18  x  y
# 0    7-01  14:08:09.299     -65  0  0
# 1    7-01  14:08:09.822     -77  0  0
# 2    7-01  14:08:09.822     -66  0  0
# 3    7-01  14:08:10.340     -66  0  0
# 4    7-01  14:08:10.860     -71  0  0
# ..    ...           ...     ... .. ..
# 228  7-01  14:11:49.706     -71  6  0
# 229  7-01  14:11:50.216     -71  6  0
# 230  7-01  14:11:50.216     -72  6  0
# 231  7-01  14:11:50.732     -73  6  0
# 232  7-01  14:11:54.751     -76  6  0
#
# [233 rows x 5 columns],      date          time  RSSI3  x  y
# 0    7-01  14:08:09.299    -55  0  0
# 1    7-01  14:08:09.822    -57  0  0
# 2    7-01  14:08:10.340    -57  0  0
# 3    7-01  14:08:10.860    -57  0  0
# 4    7-01  14:08:11.373    -55  0  0
# ..    ...           ...    ... .. ..
# 209  7-01  14:11:49.706    -66  6  0
# 210  7-01  14:11:50.216    -65  6  0
# 211  7-01  14:11:50.216    -62  6  0
# 212  7-01  14:11:50.732    -62  6  0
# 213  7-01  14:11:54.751    -65  6  0
#
# [214 rows x 5 columns],      date          time  RSSI5  x  y
# 0    7-01  14:08:09.299    -78  0  0
# 1    7-01  14:08:09.822    -72  0  0
# 2    7-01  14:08:09.822    -79  0  0
# 3    7-01  14:08:10.340    -81  0  0
# 4    7-01  14:08:10.860    -74  0  0
# ..    ...           ...    ... .. ..
# 192  7-01  14:11:49.706    -65  6  0
# 193  7-01  14:11:50.216    -66  6  0
# 194  7-01  14:11:50.216    -65  6  0
# 195  7-01  14:11:50.732    -64  6  0
# 196  7-01  14:11:54.751    -86  6  0
#
# [197 rows x 5 columns],      date          time  RSSI6  x  y
# 0    7-01  14:08:09.299    -73  0  0
# 1    7-01  14:08:09.822    -81  0  0
# 2    7-01  14:08:09.822    -68  0  0
# 3    7-01  14:08:10.340    -68  0  0
# 4    7-01  14:08:10.860    -75  0  0
# ..    ...           ...    ... .. ..
# 215  7-01  14:11:50.051    -90  6  1
# 216  7-01  14:11:49.706    -61  6  0
# 217  7-01  14:11:49.706    -64  6  0
# 218  7-01  14:11:50.216    -64  6  0
# 219  7-01  14:11:54.751    -65  6  0
#
# [220 rows x 5 columns],      date          time  RSSI7  x  y
# 0    7-01  14:08:09.299    -75  0  0
# 1    7-01  14:08:09.822    -70  0  0
# 2    7-01  14:08:10.340    -60  0  0
# 3    7-01  14:08:10.860    -68  0  0
# 4    7-01  14:08:11.373    -59  0  0
# ..    ...           ...    ... .. ..
# 211  7-01  14:11:49.706    -63  6  0
# 212  7-01  14:11:50.216    -68  6  0
# 213  7-01  14:11:50.216    -66  6  0
# 214  7-01  14:11:50.732    -66  6  0
# 215  7-01  14:11:54.751    -62  6  0
#
# [216 rows x 5 columns],      date          time  RSSI8  x  y
# 0    7-01  14:08:09.299    -67  0  0
# 1    7-01  14:08:09.299    -73  0  0
# 2    7-01  14:08:09.822    -70  0  0
# 3    7-01  14:08:10.340    -71  0  0
# 4    7-01  14:08:10.860    -82  0  0
# ..    ...           ...    ... .. ..
# 221  7-01  14:11:49.706    -64  6  0
# 222  7-01  14:11:50.216    -64  6  0
# 223  7-01  14:11:50.732    -92  6  0
# 224  7-01  14:11:50.732    -62  6  0
# 225  7-01  14:11:54.751    -68  6  0
#
# [226 rows x 5 columns],      date          time  RSSI9  x  y
# 0    7-01  14:08:09.299    -82  0  0
# 1    7-01  14:08:09.822    -71  0  0
# 2    7-01  14:08:09.822    -67  0  0
# 3    7-01  14:08:10.340    -69  0  0
# 4    7-01  14:08:10.860    -77  0  0
# ..    ...           ...    ... .. ..
# 208  7-01  14:11:49.706    -59  6  0
# 209  7-01  14:11:50.216    -64  6  0
# 210  7-01  14:11:50.216    -60  6  0
# 211  7-01  14:11:50.732    -60  6  0
# 212  7-01  14:11:54.751    -66  6  0
#
# [213 rows x 5 columns],      date          time  RSSI4  x  y
# 0    7-01  14:08:09.299    -60  0  0
# 1    7-01  14:08:09.822    -62  0  0
# 2    7-01  14:08:09.822    -58  0  0
# 3    7-01  14:08:10.340    -57  0  0
# 4    7-01  14:08:10.860    -60  0  0
# ..    ...           ...    ... .. ..
# 226  7-01  14:11:50.670    -96  6  1
# 227  7-01  14:11:50.216    -75  6  0
# 228  7-01  14:11:50.216    -81  6  0
# 229  7-01  14:11:50.732    -85  6  0
# 230  7-01  14:11:54.751    -71  6  0
#
# [231 rows x 5 columns]]

# %%
# 最初のデータフレームを指定
combined_df = data_frames[0]

# 送信時刻、座標が同じm5stackのデータを横に結合
for df in data_frames[1:]:
    combined_df = pd.merge(combined_df, df, on=["date", "time", "x", "y"], how="outer")
print(combined_df)
# Out:
#        date          time  RSSI10  x  y  RSSI11  RSSI12  RSSI13  RSSI14  \
# 0      7-01  14:08:09.299   -67.0  0  0   -85.0   -73.0   -74.0   -76.0
# 1      7-01  14:08:09.299   -67.0  0  0   -85.0   -73.0   -74.0   -76.0
# 2      7-01  14:08:09.299   -66.0  0  0   -85.0   -73.0   -74.0   -76.0
# 3      7-01  14:08:09.299   -66.0  0  0   -85.0   -73.0   -74.0   -76.0
# 4      7-01  14:08:09.822   -64.0  0  0   -73.0   -75.0   -80.0   -75.0
# ...     ...           ...     ... .. ..     ...     ...     ...     ...
# 17960  7-01  14:11:35.175     NaN  6  1     NaN     NaN     NaN     NaN
# 17961  7-01  14:11:37.182     NaN  6  1     NaN     NaN     NaN     NaN
# 17962  7-01  14:11:44.781     NaN  6  1     NaN     NaN     NaN     NaN
# 17963  7-01  14:11:46.908     NaN  6  1     NaN     NaN     NaN     NaN
# 17964  7-01  14:11:48.932     NaN  6  1     NaN     NaN     NaN     NaN
#
#        RSSI15  RSSI16  RSSI17  RSSI18  RSSI3  RSSI5  RSSI6  RSSI7  RSSI8  \
# 0       -62.0   -58.0   -49.0   -65.0  -55.0  -78.0  -73.0  -75.0  -67.0
# 1       -62.0   -58.0   -49.0   -65.0  -55.0  -78.0  -73.0  -75.0  -73.0
# 2       -62.0   -58.0   -49.0   -65.0  -55.0  -78.0  -73.0  -75.0  -67.0
# 3       -62.0   -58.0   -49.0   -65.0  -55.0  -78.0  -73.0  -75.0  -73.0
# 4       -59.0   -68.0   -49.0   -77.0  -57.0  -72.0  -81.0  -70.0  -70.0
# ...       ...     ...     ...     ...    ...    ...    ...    ...    ...
# 17960     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 17961     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 17962     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 17963     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 17964     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
#
#        RSSI9  RSSI4
# 0      -82.0  -60.0
# 1      -82.0  -60.0
# 2      -82.0  -60.0
# 3      -82.0  -60.0
# 4      -71.0  -62.0
# ...      ...    ...
# 17960  -85.0    NaN
# 17961  -85.0    NaN
# 17962  -84.0    NaN
# 17963  -84.0  -99.0
# 17964  -85.0    NaN
#
# [17965 rows x 20 columns]

# %%
# 列名を並び替える
columns_order = ['date', 'time', 'x', 'y'] + [f"RSSI{num}" for num in range(3, 19)]
combined_df = combined_df[columns_order]
print(combined_df)
# Out:
#        date          time  x  y  RSSI3  RSSI4  RSSI5  RSSI6  RSSI7  RSSI8  \
# 0      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -67.0
# 1      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -73.0
# 2      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -67.0
# 3      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -73.0
# 4      7-01  14:08:09.822  0  0  -57.0  -62.0  -72.0  -81.0  -70.0  -70.0
# ...     ...           ... .. ..    ...    ...    ...    ...    ...    ...
# 17960  7-01  14:11:35.175  6  1    NaN    NaN    NaN    NaN    NaN    NaN
# 17961  7-01  14:11:37.182  6  1    NaN    NaN    NaN    NaN    NaN    NaN
# 17962  7-01  14:11:44.781  6  1    NaN    NaN    NaN    NaN    NaN    NaN
# 17963  7-01  14:11:46.908  6  1    NaN  -99.0    NaN    NaN    NaN    NaN
# 17964  7-01  14:11:48.932  6  1    NaN    NaN    NaN    NaN    NaN    NaN
#
#        RSSI9  RSSI10  RSSI11  RSSI12  RSSI13  RSSI14  RSSI15  RSSI16  RSSI17  \
# 0      -82.0   -67.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 1      -82.0   -67.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 2      -82.0   -66.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 3      -82.0   -66.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 4      -71.0   -64.0   -73.0   -75.0   -80.0   -75.0   -59.0   -68.0   -49.0
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 17960  -85.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17961  -85.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17962  -84.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17963  -84.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17964  -85.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#        RSSI18
# 0       -65.0
# 1       -65.0
# 2       -65.0
# 3       -65.0
# 4       -77.0
# ...       ...
# 17960     NaN
# 17961     NaN
# 17962     NaN
# 17963     NaN
# 17964     NaN
#
# [17965 rows x 20 columns]

# %%
# timeの昇順に並び変える
data = combined_df.sort_values("time")
data = data.reset_index(drop=True)
print(data)
# Out:
#        date          time  x  y  RSSI3  RSSI4  RSSI5  RSSI6  RSSI7  RSSI8  \
# 0      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -67.0
# 1      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -73.0
# 2      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -67.0
# 3      7-01  14:08:09.299  0  0  -55.0  -60.0  -78.0  -73.0  -75.0  -73.0
# 4      7-01  14:08:09.822  0  0  -57.0  -58.0  -79.0  -68.0  -70.0  -70.0
# ...     ...           ... .. ..    ...    ...    ...    ...    ...    ...
# 17960  7-01  14:11:50.732  6  0  -62.0  -85.0  -64.0    NaN  -66.0  -62.0
# 17961  7-01  14:11:50.732  6  0  -62.0  -85.0  -64.0    NaN  -66.0  -92.0
# 17962  7-01  14:11:50.732  6  0  -62.0  -85.0  -64.0    NaN  -66.0  -62.0
# 17963  7-01  14:11:50.732  6  0  -62.0  -85.0  -64.0    NaN  -66.0  -92.0
# 17964  7-01  14:11:54.751  6  0  -65.0  -71.0  -86.0  -65.0  -62.0  -68.0
#
#        RSSI9  RSSI10  RSSI11  RSSI12  RSSI13  RSSI14  RSSI15  RSSI16  RSSI17  \
# 0      -82.0   -67.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 1      -82.0   -67.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 2      -82.0   -66.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 3      -82.0   -66.0   -85.0   -73.0   -74.0   -76.0   -62.0   -58.0   -49.0
# 4      -71.0   -64.0   -72.0   -75.0   -80.0   -75.0   -59.0   -61.0   -49.0
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 17960  -60.0   -72.0   -67.0   -74.0   -60.0   -64.0   -67.0   -67.0   -66.0
# 17961  -60.0   -72.0   -67.0   -74.0   -60.0   -64.0   -67.0   -67.0   -66.0
# 17962  -60.0   -72.0   -67.0   -74.0   -60.0   -64.0   -67.0   -67.0   -66.0
# 17963  -60.0   -72.0   -67.0   -74.0   -60.0   -63.0   -67.0   -67.0   -66.0
# 17964  -66.0   -74.0   -79.0   -70.0   -49.0   -71.0   -70.0   -67.0   -69.0
#
#        RSSI18
# 0       -65.0
# 1       -65.0
# 2       -65.0
# 3       -65.0
# 4       -77.0
# ...       ...
# 17960   -73.0
# 17961   -73.0
# 17962   -73.0
# 17963   -73.0
# 17964   -76.0
#
# [17965 rows x 20 columns]

# %%
#data[data['y'] == 1].to_csv(R'C:/Users/stomo/Desktop/study/logs/p10.csv', index=False)
#data[data['y'] == 0].to_csv(R'C:/Users/stomo/Desktop/study/logs/5t.csv', index=False)

# %%
# 座標ごとの総データ数
count_total = data.groupby(['x', 'y']).size().rename('data_num')

# NaNを含むデータ数
invfp_nan = data.isna().any(axis=1)
nan_count = data[invfp_nan].groupby(['x', 'y']).size().rename('nan_num')

# NaNを含まないデータ数
invfp_notnan = data.notna().all(axis=1)
notnan_count = data[invfp_notnan].groupby(['x', 'y']).size().rename('notnan_num')

# 結果をマージ
count = pd.merge(count_total, nan_count, on=["x", "y"], how="outer")
count = pd.merge(count, notnan_count, on=["x", "y"], how="outer")

# NaNを0に置き換え、int型に変換
count = count.fillna(0).astype(int)

print(count)
# Out:
#      data_num  nan_num  notnan_num
# x y
# 0 0      5313      529        4784
#   1        84       84           0
# 4 0      7190     1265        5925
#   1        99       99           0
# 6 0      5195      212        4983
#   1        84       84           0

# %%
# Nanを-200に変換
data = combined_df.fillna(-200)

# %%
# Nanを含むデータを削除
#data = data.dropna(how="any")

# %%
# Nanの数の分布をヒストグラムで表示
data_copy = data.copy()
data_copy['num_nan'] = [(data_copy.iloc[k] == -200).sum() for k in range(data_copy.shape[0])]

plt.figure(figsize=(8, 6))
plt.hist(data_copy['num_nan'], bins=range(data_copy['num_nan'].max() + 2), edgecolor='black')
plt.title('Distribution of NaN')
plt.xlabel('Number of NaN in a row')
plt.ylabel('Number of rows')
plt.xticks(range(data_copy['num_nan'].max() + 1))
plt.show()

# %%
# NaNの数が閾値より多い場合は削除
# threshold = 6
# data = data.drop(data_copy[data_copy['num_nan'] >= threshold].index)
# print(data)

# %%
# 座標ごとに50件ずつ抽出してcsvファイル作成
invfp = pd.DataFrame()
for (x, y), group in data.groupby(['x', 'y']):
    if len(group) > 0:
        if len(group) >= 50:
            invfp = pd.concat([invfp, group.sample(n=50, random_state=46)], ignore_index=True)

print(invfp.shape[0])
invfp.to_csv(R'C:/Users/sukegawa/Desktop/study/datasets/invfp/invfp_16.csv', index=False)
# Out:
# 300
